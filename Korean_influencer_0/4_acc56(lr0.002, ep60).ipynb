# %% [markdown]
# ## 데이터 세트 다운로드

# %%
# !git clone https://github.com/SESAC2023/soora_choi
# %cd soora_choi
# Out:
# Cloning into 'soora_choi'...
# remote: Enumerating objects: 1263, done.
# remote: Counting objects: 100% (472/472), done.
# remote: Compressing objects: 100% (274/274), done.
# remote: Total 1263 (delta 218), reused 413 (delta 189), pack-reused 791
# Receiving objects: 100% (1263/1263), 9.75 MiB | 19.17 MiB/s, done.
# Resolving deltas: 100% (568/568), done.
# /content/soora_choi/soora_choi/soora_choi/soora_choi/soora_choi

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
import torchvision.datasets as datasets

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split

import matplotlib.pyplot as plt
import matplotlib.image as image
import numpy as np

# %% [markdown]
# ## 데이터 세트 불러오기

# %%
transform_train = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    )
])

transform_val = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    )
])

transform_test = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    )
])

# %%
train_dataset = datasets.ImageFolder(
    root='/content/soora_choi/Korean_influencer_0/train_dataset',
    transform=transform_train
)
dataset_size = len(train_dataset)
train_size = int(dataset_size * 0.8)
val_size = dataset_size - train_size

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])
test_dataset = datasets.ImageFolder(
    root='/content/soora_choi/Korean_influencer_0/test_dataset',
    transform=transform_test
)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=8, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=8, shuffle=False)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=8, shuffle=False)

# %% [markdown]
# ## 데이터 시각화

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 60
plt.rcParams.update({'font.size': 20})


def imshow(input):
    # torch.Tensor => numpy
    input = input.numpy().transpose((1, 2, 0))
    # undo image normalization
    mean = np.array([0.5, 0.5, 0.5])
    std = np.array([0.5, 0.5, 0.5])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # display images
    plt.imshow(input)
    plt.show()


class_names = {
  0: "bts_V",
  1: "CEW",
  2: "skz_hj",
}

# load a batch of train image
iterator = iter(train_dataloader)

# visualize a batch of train image
imgs, labels = next(iterator)
out = torchvision.utils.make_grid(imgs[:4])
imshow(out)
print([class_names[labels[i].item()] for i in range(4)])
# Out:
# ['bts_V', 'skz_hj', 'bts_V', 'skz_hj']

# %% [markdown]
# ## 딥러닝 모델 학습

# %%
learning_rate = 0.002
log_step = 20
n_classes = 3

model = models.resnet50(pretrained=True)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, n_classes) # transfer learning
model = model.cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# %%
import time


def train():
    start_time = time.time()
    print(f'[Epoch: {epoch + 1} - Training]')
    model.train()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(train_dataloader):
        imgs, labels = batch
        imgs, labels = imgs.cuda(), labels.cuda()

        outputs = model(imgs)
        optimizer.zero_grad()
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total += labels.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)

        if i % log_step == log_step - 1:
            print(f'[Batch: {i + 1}] running train loss: {running_loss / total}, running train accuracy: {running_corrects / total}')

    print(f'train loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()


def validate():
    start_time = time.time()
    print(f'[Epoch: {epoch + 1} - Validation]')
    model.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(val_dataloader):
        imgs, labels = batch
        imgs, labels = imgs.cuda(), labels.cuda()

        with torch.no_grad():
            outputs = model(imgs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        total += labels.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)

        if (i == 0) or (i % log_step == log_step - 1):
            print(f'[Batch: {i + 1}] running val loss: {running_loss / total}, running val accuracy: {running_corrects / total}')

    print(f'val loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()


def test():
    start_time = time.time()
    print(f'[Test]')
    model.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(test_dataloader):
        imgs, labels = batch
        imgs, labels = imgs.cuda(), labels.cuda()

        with torch.no_grad():
            outputs = model(imgs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        total += labels.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)

        if (i == 0) or (i % log_step == log_step - 1):
            print(f'[Batch: {i + 1}] running test loss: {running_loss / total}, running test accuracy: {running_corrects / total}')

    print(f'test loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()

# %% [markdown]
# ## 학습

# %%
def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 20:
        lr /= 10
    if epoch >= 40:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr


num_epochs = 60
best_val_acc = 0
best_epoch = 0

history = []
accuracy = []
for epoch in range(num_epochs):
    adjust_learning_rate(optimizer, epoch)
    train_loss, train_acc = train()
    val_loss, val_acc = validate()
    history.append((train_loss, val_loss))
    accuracy.append((train_acc, val_acc))

    if val_acc > best_val_acc:
        print("[Info] best validation accuracy!")
        best_val_acc = val_acc
        best_epoch = epoch
        torch.save(model.state_dict(), f'best_checkpoint_epoch_{epoch + 1}.pth')

torch.save(model.state_dict(), f'last_checkpoint.pth')
# Out:
# [Epoch: 1 - Training]
# train loss: 0.017356527413843043, accuracy: 0.9583333730697632
# elapsed time: 1.5641200542449951
# [Epoch: 1 - Validation]
# [Batch: 1] running val loss: 0.1574038565158844, running val accuracy: 0.875
# val loss: 0.1659393310546875, accuracy: 0.75
# elapsed time: 0.3065814971923828
# [Info] best validation accuracy!
# [Epoch: 2 - Training]
# train loss: 0.015535467905768504, accuracy: 0.9375
# elapsed time: 1.4898707866668701
# [Epoch: 2 - Validation]
# [Batch: 1] running val loss: 0.10332836210727692, running val accuracy: 0.625
# val loss: 0.16161412000656128, accuracy: 0.6666666865348816
# elapsed time: 0.23873639106750488
# [Epoch: 3 - Training]
# train loss: 0.0027752431997214444, accuracy: 1.0
# elapsed time: 2.180629014968872
# [Epoch: 3 - Validation]
# [Batch: 1] running val loss: 0.10504446178674698, running val accuracy: 0.625
# val loss: 0.16124148666858673, accuracy: 0.5833333730697632
# elapsed time: 0.2155439853668213
# [Epoch: 4 - Training]
# train loss: 0.012630694235364595, accuracy: 0.9791666865348816
# elapsed time: 1.296091079711914
# [Epoch: 4 - Validation]
# [Batch: 1] running val loss: 0.17617252469062805, running val accuracy: 0.5
# val loss: 0.15945119659105936, accuracy: 0.5
# elapsed time: 0.21525001525878906
# [Epoch: 5 - Training]
# train loss: 0.003624272139859386, accuracy: 1.0
# elapsed time: 1.2568962574005127
# [Epoch: 5 - Validation]
# [Batch: 1] running val loss: 0.22894686460494995, running val accuracy: 0.625
# val loss: 0.24000784754753113, accuracy: 0.5833333730697632
# elapsed time: 0.2149672508239746
# [Epoch: 6 - Training]
# train loss: 0.002803345628005142, accuracy: 1.0
# elapsed time: 1.2588942050933838
# [Epoch: 6 - Validation]
# [Batch: 1] running val loss: 0.1843481957912445, running val accuracy: 0.5
# val loss: 0.22831917802492777, accuracy: 0.5
# elapsed time: 0.20895695686340332
# [Epoch: 7 - Training]
# train loss: 0.004570283553524253, accuracy: 1.0
# elapsed time: 1.25600004196167
# [Epoch: 7 - Validation]
# [Batch: 1] running val loss: 0.1637510508298874, running val accuracy: 0.625
# val loss: 0.19113371769587198, accuracy: 0.5833333730697632
# elapsed time: 0.2173018455505371
# [Epoch: 8 - Training]
# train loss: 0.0007036688475636765, accuracy: 1.0
# elapsed time: 1.3225860595703125
# [Epoch: 8 - Validation]
# [Batch: 1] running val loss: 0.15997432172298431, running val accuracy: 0.625
# val loss: 0.18902126948038736, accuracy: 0.5833333730697632
# elapsed time: 0.3006577491760254
# [Epoch: 9 - Training]
# train loss: 0.005972624281033252, accuracy: 0.9791666865348816
# elapsed time: 1.6296100616455078
# [Epoch: 9 - Validation]
# [Batch: 1] running val loss: 0.23000037670135498, running val accuracy: 0.75
# val loss: 0.23473710815111795, accuracy: 0.6666666865348816
# elapsed time: 0.29512929916381836
# [Epoch: 10 - Training]
# train loss: 0.04562476315186359, accuracy: 0.9375
# elapsed time: 1.2524547576904297
# [Epoch: 10 - Validation]
# [Batch: 1] running val loss: 0.23046115040779114, running val accuracy: 0.75
# val loss: 0.2645437717437744, accuracy: 0.6666666865348816
# elapsed time: 0.2112729549407959
# [Epoch: 11 - Training]
# train loss: 0.0015464939739710342, accuracy: 1.0
# elapsed time: 1.2652781009674072
# [Epoch: 11 - Validation]
# [Batch: 1] running val loss: 0.18496054410934448, running val accuracy: 0.5
# val loss: 0.1675784389177958, accuracy: 0.5
# elapsed time: 0.20957207679748535
# [Epoch: 12 - Training]
# train loss: 0.008057201608608011, accuracy: 0.9791666865348816
# elapsed time: 1.260068416595459
# [Epoch: 12 - Validation]
# [Batch: 1] running val loss: 0.26456454396247864, running val accuracy: 0.5
# val loss: 0.2695535222689311, accuracy: 0.5
# elapsed time: 0.22220516204833984
# [Epoch: 13 - Training]
# train loss: 0.007049833477746385, accuracy: 0.9791666865348816
# elapsed time: 1.282616376876831
# [Epoch: 13 - Validation]
# [Batch: 1] running val loss: 0.2583097219467163, running val accuracy: 0.5
# val loss: 0.2686016360918681, accuracy: 0.5
# elapsed time: 0.22681379318237305
# [Epoch: 14 - Training]
# train loss: 0.025624994256456073, accuracy: 0.8958333730697632
# elapsed time: 1.2530934810638428
# [Epoch: 14 - Validation]
# [Batch: 1] running val loss: 0.1773262470960617, running val accuracy: 0.625
# val loss: 0.1794796884059906, accuracy: 0.5833333730697632
# elapsed time: 0.21420907974243164
# [Epoch: 15 - Training]
# train loss: 0.016630976810120046, accuracy: 0.9791666865348816
# elapsed time: 1.2697088718414307
# [Epoch: 15 - Validation]
# [Batch: 1] running val loss: 0.16757148504257202, running val accuracy: 0.625
# val loss: 0.17440691590309143, accuracy: 0.5833333730697632
# elapsed time: 0.21311712265014648
# [Epoch: 16 - Training]
# train loss: 0.0029249850631458685, accuracy: 1.0
# elapsed time: 1.2729442119598389
# [Epoch: 16 - Validation]
# [Batch: 1] running val loss: 0.11535295844078064, running val accuracy: 0.625
# val loss: 0.188569704691569, accuracy: 0.5833333730697632
# elapsed time: 0.31040287017822266
# [Epoch: 17 - Training]
# train loss: 0.0019861142282024957, accuracy: 1.0
# elapsed time: 1.6212451457977295
# [Epoch: 17 - Validation]
# [Batch: 1] running val loss: 0.19632747769355774, running val accuracy: 0.5
# val loss: 0.17339098950227103, accuracy: 0.5833333730697632
# elapsed time: 0.2915177345275879
# [Epoch: 18 - Training]
# train loss: 0.028405817865859717, accuracy: 0.9375
# elapsed time: 1.304896593093872
# [Epoch: 18 - Validation]
# [Batch: 1] running val loss: 0.17655465006828308, running val accuracy: 0.625
# val loss: 0.23155112067858377, accuracy: 0.5833333730697632
# elapsed time: 0.2182788848876953
# [Epoch: 19 - Training]
# train loss: 0.0255263619304363, accuracy: 0.8958333730697632
# elapsed time: 1.2629363536834717
# [Epoch: 19 - Validation]
# [Batch: 1] running val loss: 0.19546684622764587, running val accuracy: 0.5
# val loss: 0.17267130812009177, accuracy: 0.5833333730697632
# elapsed time: 0.21625661849975586
# [Epoch: 20 - Training]
# train loss: 0.007784716714619814, accuracy: 0.9583333730697632
# elapsed time: 1.266413688659668
# [Epoch: 20 - Validation]
# [Batch: 1] running val loss: 0.17632237076759338, running val accuracy: 0.5
# val loss: 0.16006759802500406, accuracy: 0.5833333730697632
# elapsed time: 0.2102975845336914
# [Epoch: 21 - Training]
# train loss: 0.014057066623839395, accuracy: 0.9583333730697632
# elapsed time: 1.2651333808898926
# [Epoch: 21 - Validation]
# [Batch: 1] running val loss: 0.10184915363788605, running val accuracy: 0.75
# val loss: 0.12837728361288706, accuracy: 0.6666666865348816
# elapsed time: 0.23163890838623047
# [Epoch: 22 - Training]
# train loss: 0.006918299201061018, accuracy: 0.9583333730697632
# elapsed time: 1.2526273727416992
# [Epoch: 22 - Validation]
# [Batch: 1] running val loss: 0.0978243425488472, running val accuracy: 0.875
# val loss: 0.169534241159757, accuracy: 0.75
# elapsed time: 0.21896982192993164
# [Epoch: 23 - Training]
# train loss: 0.0007579355539443592, accuracy: 1.0
# elapsed time: 1.2615351676940918
# [Epoch: 23 - Validation]
# [Batch: 1] running val loss: 0.10032361000776291, running val accuracy: 0.625
# val loss: 0.16781466702620187, accuracy: 0.5833333730697632
# elapsed time: 0.22251081466674805
# [Epoch: 24 - Training]
# train loss: 0.0019374805488041602, accuracy: 1.0
# elapsed time: 1.2726325988769531
# [Epoch: 24 - Validation]
# [Batch: 1] running val loss: 0.16755947470664978, running val accuracy: 0.625
# val loss: 0.2114468514919281, accuracy: 0.5833333730697632
# elapsed time: 0.27722859382629395
# [Epoch: 25 - Training]
# train loss: 0.0010462180410589401, accuracy: 1.0
# elapsed time: 1.6296308040618896
# [Epoch: 25 - Validation]
# [Batch: 1] running val loss: 0.09364871680736542, running val accuracy: 0.75
# val loss: 0.1608498990535736, accuracy: 0.6666666865348816
# elapsed time: 0.31082844734191895
# [Epoch: 26 - Training]
# train loss: 0.013205772644141689, accuracy: 0.9375
# elapsed time: 1.3631038665771484
# [Epoch: 26 - Validation]
# [Batch: 1] running val loss: 0.15441498160362244, running val accuracy: 0.875
# val loss: 0.14214752117792764, accuracy: 0.75
# elapsed time: 0.22795891761779785
# [Epoch: 27 - Training]
# train loss: 0.0005048472194175702, accuracy: 1.0
# elapsed time: 1.2702734470367432
# [Epoch: 27 - Validation]
# [Batch: 1] running val loss: 0.1667822301387787, running val accuracy: 0.625
# val loss: 0.15123375256856283, accuracy: 0.5833333730697632
# elapsed time: 0.21976208686828613
# [Epoch: 28 - Training]
# train loss: 0.0036092569474324896, accuracy: 1.0
# elapsed time: 1.274719476699829
# [Epoch: 28 - Validation]
# [Batch: 1] running val loss: 0.18080657720565796, running val accuracy: 0.5
# val loss: 0.16045347601175308, accuracy: 0.5
# elapsed time: 0.21380019187927246
# [Epoch: 29 - Training]
# train loss: 0.0017338491985962416, accuracy: 1.0
# elapsed time: 1.262953519821167
# [Epoch: 29 - Validation]
# [Batch: 1] running val loss: 0.1802869588136673, running val accuracy: 0.5
# val loss: 0.22530052065849304, accuracy: 0.5
# elapsed time: 0.22173190116882324
# [Epoch: 30 - Training]
# train loss: 0.001094253913227779, accuracy: 1.0
# elapsed time: 1.2659211158752441
# [Epoch: 30 - Validation]
# [Batch: 1] running val loss: 0.1700214147567749, running val accuracy: 0.5
# val loss: 0.17439611752827963, accuracy: 0.5
# elapsed time: 0.21173524856567383
# [Epoch: 31 - Training]
# train loss: 0.00415288989218728, accuracy: 0.9791666865348816
# elapsed time: 1.2671852111816406
# [Epoch: 31 - Validation]
# [Batch: 1] running val loss: 0.23133684694766998, running val accuracy: 0.625
# val loss: 0.2543221016724904, accuracy: 0.5833333730697632
# elapsed time: 0.20935750007629395
# [Epoch: 32 - Training]
# train loss: 0.0012433185377934326, accuracy: 1.0
# elapsed time: 1.2397263050079346
# [Epoch: 32 - Validation]
# [Batch: 1] running val loss: 0.24681811034679413, running val accuracy: 0.5
# val loss: 0.24419487019379935, accuracy: 0.5
# elapsed time: 0.23161768913269043
# [Epoch: 33 - Training]
# train loss: 0.01899573457679556, accuracy: 0.9375
# elapsed time: 1.6549437046051025
# [Epoch: 33 - Validation]
# [Batch: 1] running val loss: 0.09624245017766953, running val accuracy: 0.625
# val loss: 0.1044984832406044, accuracy: 0.5833333730697632
# elapsed time: 0.3039712905883789
# [Epoch: 34 - Training]
# train loss: 0.022700087178236572, accuracy: 0.9375
# elapsed time: 1.4339308738708496
# [Epoch: 34 - Validation]
# [Batch: 1] running val loss: 0.23319318890571594, running val accuracy: 0.625
# val loss: 0.2382016976674398, accuracy: 0.5833333730697632
# elapsed time: 0.2192220687866211
# [Epoch: 35 - Training]
# train loss: 0.0033616464061196893, accuracy: 0.9791666865348816
# elapsed time: 1.2604029178619385
# [Epoch: 35 - Validation]
# [Batch: 1] running val loss: 0.16889101266860962, running val accuracy: 0.625
# val loss: 0.21675708889961243, accuracy: 0.5833333730697632
# elapsed time: 0.22523140907287598
# [Epoch: 36 - Training]
# train loss: 0.004169281940752019, accuracy: 1.0
# elapsed time: 1.2636122703552246
# [Epoch: 36 - Validation]
# [Batch: 1] running val loss: 0.15612100064754486, running val accuracy: 0.625
# val loss: 0.16478712360064188, accuracy: 0.5833333730697632
# elapsed time: 0.22062158584594727
# [Epoch: 37 - Training]
# train loss: 0.0034866275988557995, accuracy: 1.0
# elapsed time: 1.2582519054412842
# [Epoch: 37 - Validation]
# [Batch: 1] running val loss: 0.23175016045570374, running val accuracy: 0.75
# val loss: 0.19538198908170065, accuracy: 0.6666666865348816
# elapsed time: 0.22034645080566406
# [Epoch: 38 - Training]
# train loss: 0.0007325742481043562, accuracy: 1.0
# elapsed time: 1.2615022659301758
# [Epoch: 38 - Validation]
# [Batch: 1] running val loss: 0.10313647240400314, running val accuracy: 0.625
# val loss: 0.15324262281258902, accuracy: 0.5833333730697632
# elapsed time: 0.22247695922851562
# [Epoch: 39 - Training]
# train loss: 0.0036470255169357793, accuracy: 0.9791666865348816
# elapsed time: 1.266845941543579
# [Epoch: 39 - Validation]
# [Batch: 1] running val loss: 0.16893267631530762, running val accuracy: 0.625
# val loss: 0.17522989213466644, accuracy: 0.5833333730697632
# elapsed time: 0.21516633033752441
# [Epoch: 40 - Training]
# train loss: 0.004108402310521342, accuracy: 0.9791666865348816
# elapsed time: 1.27089524269104
# [Epoch: 40 - Validation]
# [Batch: 1] running val loss: 0.171389639377594, running val accuracy: 0.625
# val loss: 0.22057318687438965, accuracy: 0.5833333730697632
# elapsed time: 0.22557663917541504
# [Epoch: 41 - Training]
# train loss: 0.002388392017261746, accuracy: 1.0
# elapsed time: 2.585317373275757
# [Epoch: 41 - Validation]
# [Batch: 1] running val loss: 0.11080130189657211, running val accuracy: 0.625
# val loss: 0.1812886744737625, accuracy: 0.5833333730697632
# elapsed time: 0.43746447563171387
# [Epoch: 42 - Training]
# train loss: 0.002291296567515625, accuracy: 1.0
# elapsed time: 1.6858322620391846
# [Epoch: 42 - Validation]
# [Batch: 1] running val loss: 0.23732608556747437, running val accuracy: 0.625
# val loss: 0.2434074580669403, accuracy: 0.5833333730697632
# elapsed time: 0.21779251098632812
# [Epoch: 43 - Training]
# train loss: 0.0014852188226844494, accuracy: 1.0
# elapsed time: 1.2742996215820312
# [Epoch: 43 - Validation]
# [Batch: 1] running val loss: 0.11232353746891022, running val accuracy: 0.5
# val loss: 0.1589557429154714, accuracy: 0.5833333730697632
# elapsed time: 0.21378540992736816
# [Epoch: 44 - Training]
# train loss: 0.006317424848020892, accuracy: 0.9791666865348816
# elapsed time: 1.2855639457702637
# [Epoch: 44 - Validation]
# [Batch: 1] running val loss: 0.17294159531593323, running val accuracy: 0.625
# val loss: 0.21655765175819397, accuracy: 0.5833333730697632
# elapsed time: 0.21738553047180176
# [Epoch: 45 - Training]
# train loss: 0.003182385829859413, accuracy: 1.0
# elapsed time: 1.2777531147003174
# [Epoch: 45 - Validation]
# [Batch: 1] running val loss: 0.1920594871044159, running val accuracy: 0.5
# val loss: 0.21761158108711243, accuracy: 0.5
# elapsed time: 0.2206864356994629
# [Epoch: 46 - Training]
# train loss: 0.000426496307530518, accuracy: 1.0
# elapsed time: 1.2811169624328613
# [Epoch: 46 - Validation]
# [Batch: 1] running val loss: 0.16061171889305115, running val accuracy: 0.75
# val loss: 0.1911811133225759, accuracy: 0.6666666865348816
# elapsed time: 0.22124528884887695
# [Epoch: 47 - Training]
# train loss: 0.009259466957397914, accuracy: 0.9791666865348816
# elapsed time: 1.2851717472076416
# [Epoch: 47 - Validation]
# [Batch: 1] running val loss: 0.10536559671163559, running val accuracy: 0.625
# val loss: 0.13206321001052856, accuracy: 0.5833333730697632
# elapsed time: 0.22166872024536133
# [Epoch: 48 - Training]
# train loss: 0.0005077835691433089, accuracy: 1.0
# elapsed time: 1.3868780136108398
# [Epoch: 48 - Validation]
# [Batch: 1] running val loss: 0.10773499310016632, running val accuracy: 0.625
# val loss: 0.11268466711044312, accuracy: 0.5833333730697632
# elapsed time: 0.29907965660095215
# [Epoch: 49 - Training]
# train loss: 0.008438060382710924, accuracy: 0.9791666865348816
# elapsed time: 1.6148810386657715
# [Epoch: 49 - Validation]
# [Batch: 1] running val loss: 0.25532734394073486, running val accuracy: 0.5
# val loss: 0.2774939139684041, accuracy: 0.5
# elapsed time: 0.26259684562683105
# [Epoch: 50 - Training]
# train loss: 0.004760899850225542, accuracy: 0.9791666865348816
# elapsed time: 1.267030954360962
# [Epoch: 50 - Validation]
# [Batch: 1] running val loss: 0.16995121538639069, running val accuracy: 0.625
# val loss: 0.20352831482887268, accuracy: 0.5833333730697632
# elapsed time: 0.2220923900604248
# [Epoch: 51 - Training]
# train loss: 0.007376775965288592, accuracy: 0.9791666865348816
# elapsed time: 1.2933576107025146
# [Epoch: 51 - Validation]
# [Batch: 1] running val loss: 0.24855263531208038, running val accuracy: 0.5
# val loss: 0.22617346545060477, accuracy: 0.5
# elapsed time: 0.20815658569335938
# [Epoch: 52 - Training]
# train loss: 0.003919526168222849, accuracy: 1.0
# elapsed time: 1.2596759796142578
# [Epoch: 52 - Validation]
# [Batch: 1] running val loss: 0.24697580933570862, running val accuracy: 0.5
# val loss: 0.25250370303789776, accuracy: 0.5
# elapsed time: 0.22408485412597656
# [Epoch: 53 - Training]
# train loss: 0.0013569383299909532, accuracy: 1.0
# elapsed time: 1.2669684886932373
# [Epoch: 53 - Validation]
# [Batch: 1] running val loss: 0.1111242026090622, running val accuracy: 0.5
# val loss: 0.18012283245722452, accuracy: 0.5
# elapsed time: 0.20993614196777344
# [Epoch: 54 - Training]
# train loss: 0.020120824706585456, accuracy: 0.9166666865348816
# elapsed time: 1.251906156539917
# [Epoch: 54 - Validation]
# [Batch: 1] running val loss: 0.16990473866462708, running val accuracy: 0.625
# val loss: 0.22657017906506857, accuracy: 0.5833333730697632
# elapsed time: 0.22480988502502441
# [Epoch: 55 - Training]
# train loss: 0.0054997323944310965, accuracy: 0.9791666865348816
# elapsed time: 1.269529104232788
# [Epoch: 55 - Validation]
# [Batch: 1] running val loss: 0.26274237036705017, running val accuracy: 0.5
# val loss: 0.23925930261611938, accuracy: 0.5
# elapsed time: 0.21996188163757324
# [Epoch: 56 - Training]
# train loss: 0.0012345347374017972, accuracy: 1.0
# elapsed time: 1.344578504562378
# [Epoch: 56 - Validation]
# [Batch: 1] running val loss: 0.1652500331401825, running val accuracy: 0.75
# val loss: 0.2151277760664622, accuracy: 0.6666666865348816
# elapsed time: 0.3218345642089844
# [Epoch: 57 - Training]
# train loss: 0.011282621208617153, accuracy: 0.9583333730697632
# elapsed time: 1.615799903869629
# [Epoch: 57 - Validation]
# [Batch: 1] running val loss: 0.11913762986660004, running val accuracy: 0.5
# val loss: 0.18899578849474588, accuracy: 0.5
# elapsed time: 0.2970740795135498
# [Epoch: 58 - Training]
# train loss: 0.005505164435210948, accuracy: 0.9791666865348816
# elapsed time: 1.2902019023895264
# [Epoch: 58 - Validation]
# [Batch: 1] running val loss: 0.2357896864414215, running val accuracy: 0.625
# val loss: 0.24490399161974588, accuracy: 0.5833333730697632
# elapsed time: 0.21636700630187988
# [Epoch: 59 - Training]
# train loss: 0.003178726236607569, accuracy: 1.0
# elapsed time: 1.2800953388214111
# [Epoch: 59 - Validation]
# [Batch: 1] running val loss: 0.243783101439476, running val accuracy: 0.625
# val loss: 0.2049885243177414, accuracy: 0.5833333730697632
# elapsed time: 0.21048498153686523
# [Epoch: 60 - Training]
# train loss: 0.002242036372384367, accuracy: 1.0
# elapsed time: 1.2569043636322021
# [Epoch: 60 - Validation]
# [Batch: 1] running val loss: 0.17851585149765015, running val accuracy: 0.625
# val loss: 0.20886990427970886, accuracy: 0.6666666865348816
# elapsed time: 0.22035455703735352

# %% [markdown]
# ## 결과 시각화

# %%
plt.plot([x[0] for x in history], 'b', label='train')
plt.plot([x[1] for x in history], 'r--',label='validation')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot([x[0] for x in accuracy], 'b', label='train')
plt.plot([x[1] for x in accuracy], 'r--',label='validation')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
model = models.resnet50(pretrained=True)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 3) # transfer learning
model = model.cuda()
model_path = 'last_checkpoint.pth'
model.load_state_dict(torch.load(model_path))

test_loss, test_accuracy = test()
print(f"Test loss: {test_loss:.8f}")
print(f"Test accuracy: {test_accuracy * 100.:.2f}%")
# Out:
# [Test]
# [Batch: 1] running test loss: 0.04631170630455017, running test accuracy: 0.875
# test loss: 0.24762920141220093, accuracy: 0.5666667222976685
# elapsed time: 0.5398454666137695
# Test loss: 0.24762920
# Test accuracy: 56.67%
