# %% [markdown]
# ## 데이터 세트 다운로드

# %%
# !git clone https://github.com/SESAC2023/soora_choi
# %cd soora_choi
# Out:
# Cloning into 'soora_choi'...
# remote: Enumerating objects: 1263, done.
# remote: Counting objects: 100% (472/472), done.
# remote: Compressing objects: 100% (274/274), done.
# remote: Total 1263 (delta 218), reused 413 (delta 189), pack-reused 791
# Receiving objects: 100% (1263/1263), 9.75 MiB | 19.17 MiB/s, done.
# Resolving deltas: 100% (568/568), done.
# /content/soora_choi/soora_choi/soora_choi/soora_choi/soora_choi

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
import torchvision.datasets as datasets

import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import random_split

import matplotlib.pyplot as plt
import matplotlib.image as image
import numpy as np

# %% [markdown]
# ## 데이터 세트 불러오기

# %%
transform_train = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    )
])

transform_val = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    )
])

transform_test = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(
        mean=[0.5, 0.5, 0.5],
        std=[0.5, 0.5, 0.5]
    )
])

# %%
train_dataset = datasets.ImageFolder(
    root='/content/soora_choi/Korean_influencer_0/train_dataset',
    transform=transform_train
)
dataset_size = len(train_dataset)
train_size = int(dataset_size * 0.8)
val_size = dataset_size - train_size

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])
test_dataset = datasets.ImageFolder(
    root='/content/soora_choi/Korean_influencer_0/test_dataset',
    transform=transform_test
)

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size=8, shuffle=True)
val_dataloader = torch.utils.data.DataLoader(val_dataset, batch_size=8, shuffle=False)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size=8, shuffle=False)

# %% [markdown]
# ## 데이터 시각화

# %%
plt.rcParams['figure.figsize'] = [12, 8]
plt.rcParams['figure.dpi'] = 60
plt.rcParams.update({'font.size': 20})


def imshow(input):
    # torch.Tensor => numpy
    input = input.numpy().transpose((1, 2, 0))
    # undo image normalization
    mean = np.array([0.5, 0.5, 0.5])
    std = np.array([0.5, 0.5, 0.5])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # display images
    plt.imshow(input)
    plt.show()


class_names = {
  0: "bts_V",
  1: "CEW",
  2: "skz_hj",
}

# load a batch of train image
iterator = iter(train_dataloader)

# visualize a batch of train image
imgs, labels = next(iterator)
out = torchvision.utils.make_grid(imgs[:4])
imshow(out)
print([class_names[labels[i].item()] for i in range(4)])
# Out:
# ['bts_V', 'skz_hj', 'bts_V', 'skz_hj']

# %% [markdown]
# ## 딥러닝 모델 학습

# %%
learning_rate = 0.01
log_step = 20
n_classes = 3

model = models.resnet50(pretrained=True)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, n_classes) # transfer learning
model = model.cuda()

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# %%
import time


def train():
    start_time = time.time()
    print(f'[Epoch: {epoch + 1} - Training]')
    model.train()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(train_dataloader):
        imgs, labels = batch
        imgs, labels = imgs.cuda(), labels.cuda()

        outputs = model(imgs)
        optimizer.zero_grad()
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        total += labels.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)

        if i % log_step == log_step - 1:
            print(f'[Batch: {i + 1}] running train loss: {running_loss / total}, running train accuracy: {running_corrects / total}')

    print(f'train loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()


def validate():
    start_time = time.time()
    print(f'[Epoch: {epoch + 1} - Validation]')
    model.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(val_dataloader):
        imgs, labels = batch
        imgs, labels = imgs.cuda(), labels.cuda()

        with torch.no_grad():
            outputs = model(imgs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        total += labels.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)

        if (i == 0) or (i % log_step == log_step - 1):
            print(f'[Batch: {i + 1}] running val loss: {running_loss / total}, running val accuracy: {running_corrects / total}')

    print(f'val loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()


def test():
    start_time = time.time()
    print(f'[Test]')
    model.eval()
    total = 0
    running_loss = 0.0
    running_corrects = 0

    for i, batch in enumerate(test_dataloader):
        imgs, labels = batch
        imgs, labels = imgs.cuda(), labels.cuda()

        with torch.no_grad():
            outputs = model(imgs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

        total += labels.shape[0]
        running_loss += loss.item()
        running_corrects += torch.sum(preds == labels.data)

        if (i == 0) or (i % log_step == log_step - 1):
            print(f'[Batch: {i + 1}] running test loss: {running_loss / total}, running test accuracy: {running_corrects / total}')

    print(f'test loss: {running_loss / total}, accuracy: {running_corrects / total}')
    print("elapsed time:", time.time() - start_time)
    return running_loss / total, (running_corrects / total).item()

# %% [markdown]
# ## 학습

# %%
def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 5:
        lr /= 10
    if epoch >= 10:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr


num_epochs = 100
best_val_acc = 0
best_epoch = 0

history = []
accuracy = []
for epoch in range(num_epochs):
    adjust_learning_rate(optimizer, epoch)
    train_loss, train_acc = train()
    val_loss, val_acc = validate()
    history.append((train_loss, val_loss))
    accuracy.append((train_acc, val_acc))

    if val_acc > best_val_acc:
        print("[Info] best validation accuracy!")
        best_val_acc = val_acc
        best_epoch = epoch
        torch.save(model.state_dict(), f'best_checkpoint_epoch_{epoch + 1}.pth')

torch.save(model.state_dict(), f'last_checkpoint.pth')
# Out:
# [Epoch: 1 - Training]
# train loss: 0.012905257870443165, accuracy: 0.9583333730697632
# elapsed time: 1.3152973651885986
# [Epoch: 1 - Validation]
# [Batch: 1] running val loss: 0.23882631957530975, running val accuracy: 0.5
# val loss: 0.23948442935943604, accuracy: 0.5
# elapsed time: 0.21159577369689941
# [Info] best validation accuracy!
# [Epoch: 2 - Training]
# train loss: 0.0029555154760601, accuracy: 1.0
# elapsed time: 1.243936538696289
# [Epoch: 2 - Validation]
# [Batch: 1] running val loss: 0.18794214725494385, running val accuracy: 0.5
# val loss: 0.18624820311864218, accuracy: 0.5
# elapsed time: 0.21764516830444336
# [Epoch: 3 - Training]
# train loss: 0.006099433093671299, accuracy: 0.9791666865348816
# elapsed time: 1.2499628067016602
# [Epoch: 3 - Validation]
# [Batch: 1] running val loss: 0.18285220861434937, running val accuracy: 0.5
# val loss: 0.20187434057394663, accuracy: 0.5
# elapsed time: 0.2077178955078125
# [Epoch: 4 - Training]
# train loss: 0.0014088410534895957, accuracy: 1.0
# elapsed time: 1.4403023719787598
# [Epoch: 4 - Validation]
# [Batch: 1] running val loss: 0.25414082407951355, running val accuracy: 0.5
# val loss: 0.25852325558662415, accuracy: 0.5
# elapsed time: 0.2977309226989746
# [Epoch: 5 - Training]
# train loss: 0.006165595987113193, accuracy: 1.0
# elapsed time: 1.5171468257904053
# [Epoch: 5 - Validation]
# [Batch: 1] running val loss: 0.11012342572212219, running val accuracy: 0.625
# val loss: 0.16056417425473532, accuracy: 0.5833333730697632
# elapsed time: 0.20636343955993652
# [Info] best validation accuracy!
# [Epoch: 6 - Training]
# train loss: 0.011974764992676986, accuracy: 0.9583333730697632
# elapsed time: 1.2463710308074951
# [Epoch: 6 - Validation]
# [Batch: 1] running val loss: 0.1605905145406723, running val accuracy: 0.75
# val loss: 0.2091411848862966, accuracy: 0.6666666865348816
# elapsed time: 0.2059330940246582
# [Info] best validation accuracy!
# [Epoch: 7 - Training]
# train loss: 0.003407684899381517, accuracy: 1.0
# elapsed time: 1.2330358028411865
# [Epoch: 7 - Validation]
# [Batch: 1] running val loss: 0.16743585467338562, running val accuracy: 0.75
# val loss: 0.20008546113967896, accuracy: 0.6666666865348816
# elapsed time: 0.20348763465881348
# [Epoch: 8 - Training]
# train loss: 0.0018954481562711105, accuracy: 1.0
# elapsed time: 1.2324049472808838
# [Epoch: 8 - Validation]
# [Batch: 1] running val loss: 0.2471737265586853, running val accuracy: 0.5
# val loss: 0.20891196529070535, accuracy: 0.5
# elapsed time: 0.21002626419067383
# [Epoch: 9 - Training]
# train loss: 0.006521237252551752, accuracy: 0.9791666865348816
# elapsed time: 1.2305657863616943
# [Epoch: 9 - Validation]
# [Batch: 1] running val loss: 0.2420455515384674, running val accuracy: 0.5
# val loss: 0.2647321820259094, accuracy: 0.5
# elapsed time: 0.2055981159210205
# [Epoch: 10 - Training]
# train loss: 0.012431024559191428, accuracy: 0.9791666865348816
# elapsed time: 1.242156982421875
# [Epoch: 10 - Validation]
# [Batch: 1] running val loss: 0.26158851385116577, running val accuracy: 0.5
# val loss: 0.2854698995749156, accuracy: 0.5
# elapsed time: 0.21222853660583496
# [Epoch: 11 - Training]
# train loss: 0.0019719992099756687, accuracy: 1.0
# elapsed time: 1.2477352619171143
# [Epoch: 11 - Validation]
# [Batch: 1] running val loss: 0.1955675482749939, running val accuracy: 0.5
# val loss: 0.19138472278912863, accuracy: 0.5
# elapsed time: 0.21463918685913086
# [Epoch: 12 - Training]
# train loss: 0.00457051826621561, accuracy: 1.0
# elapsed time: 1.4287981986999512
# [Epoch: 12 - Validation]
# [Batch: 1] running val loss: 0.26519930362701416, running val accuracy: 0.5
# val loss: 0.2860766251881917, accuracy: 0.5
# elapsed time: 0.3044698238372803
# [Epoch: 13 - Training]
# train loss: 0.0031536106847246024, accuracy: 0.9791666865348816
# elapsed time: 1.560476541519165
# [Epoch: 13 - Validation]
# [Batch: 1] running val loss: 0.23620212078094482, running val accuracy: 0.625
# val loss: 0.2637685736020406, accuracy: 0.5833333730697632
# elapsed time: 0.20902156829833984
# [Epoch: 14 - Training]
# train loss: 0.005314448634938647, accuracy: 0.9791666865348816
# elapsed time: 1.2776665687561035
# [Epoch: 14 - Validation]
# [Batch: 1] running val loss: 0.17488789558410645, running val accuracy: 0.625
# val loss: 0.15797854463259378, accuracy: 0.5833333730697632
# elapsed time: 0.2072286605834961
# [Epoch: 15 - Training]
# train loss: 0.0015771963614194344, accuracy: 1.0
# elapsed time: 1.2389590740203857
# [Epoch: 15 - Validation]
# [Batch: 1] running val loss: 0.24717721343040466, running val accuracy: 0.5
# val loss: 0.20442638297875723, accuracy: 0.5
# elapsed time: 0.2051529884338379
# [Epoch: 16 - Training]
# train loss: 0.0006545441574417055, accuracy: 1.0
# elapsed time: 1.2328641414642334
# [Epoch: 16 - Validation]
# [Batch: 1] running val loss: 0.1604483723640442, running val accuracy: 0.625
# val loss: 0.21280438701311746, accuracy: 0.5833333730697632
# elapsed time: 0.20572257041931152
# [Epoch: 17 - Training]
# train loss: 0.007357851146177079, accuracy: 0.9791666865348816
# elapsed time: 1.237065315246582
# [Epoch: 17 - Validation]
# [Batch: 1] running val loss: 0.18360036611557007, running val accuracy: 0.5
# val loss: 0.2263668179512024, accuracy: 0.5
# elapsed time: 0.20737433433532715
# [Epoch: 18 - Training]
# train loss: 0.0005418796693750968, accuracy: 1.0
# elapsed time: 1.2435462474822998
# [Epoch: 18 - Validation]
# [Batch: 1] running val loss: 0.25133219361305237, running val accuracy: 0.5
# val loss: 0.20915521929661432, accuracy: 0.5
# elapsed time: 0.20322632789611816
# [Epoch: 19 - Training]
# train loss: 0.0010384559888431493, accuracy: 1.0
# elapsed time: 1.2594680786132812
# [Epoch: 19 - Validation]
# [Batch: 1] running val loss: 0.23667827248573303, running val accuracy: 0.625
# val loss: 0.24134876330693564, accuracy: 0.5833333730697632
# elapsed time: 0.2098219394683838
# [Epoch: 20 - Training]
# train loss: 0.0021257146775800115, accuracy: 1.0
# elapsed time: 1.3538897037506104
# [Epoch: 20 - Validation]
# [Batch: 1] running val loss: 0.09689245373010635, running val accuracy: 0.75
# val loss: 0.1670448233683904, accuracy: 0.6666666865348816
# elapsed time: 0.30740809440612793
# [Epoch: 21 - Training]
# train loss: 0.0020300424621382263, accuracy: 1.0
# elapsed time: 1.611037254333496
# [Epoch: 21 - Validation]
# [Batch: 1] running val loss: 0.2348095178604126, running val accuracy: 0.625
# val loss: 0.19984900951385498, accuracy: 0.5833333730697632
# elapsed time: 0.2642021179199219
# [Epoch: 22 - Training]
# train loss: 0.03851910673013966, accuracy: 0.8958333730697632
# elapsed time: 1.2499749660491943
# [Epoch: 22 - Validation]
# [Batch: 1] running val loss: 0.19980071485042572, running val accuracy: 0.5
# val loss: 0.2125092645486196, accuracy: 0.5
# elapsed time: 0.20885419845581055
# [Epoch: 23 - Training]
# train loss: 0.007072025056307514, accuracy: 0.9583333730697632
# elapsed time: 1.2632908821105957
# [Epoch: 23 - Validation]
# [Batch: 1] running val loss: 0.24110627174377441, running val accuracy: 0.5
# val loss: 0.23879567782084146, accuracy: 0.5
# elapsed time: 0.20746231079101562
# [Epoch: 24 - Training]
# train loss: 0.006009947684409174, accuracy: 0.9791666865348816
# elapsed time: 1.251512050628662
# [Epoch: 24 - Validation]
# [Batch: 1] running val loss: 0.1727643758058548, running val accuracy: 0.625
# val loss: 0.19638396302858988, accuracy: 0.5833333730697632
# elapsed time: 0.2117016315460205
# [Epoch: 25 - Training]
# train loss: 0.0005538365294341929, accuracy: 1.0
# elapsed time: 1.2328619956970215
# [Epoch: 25 - Validation]
# [Batch: 1] running val loss: 0.2236948311328888, running val accuracy: 0.625
# val loss: 0.24819788336753845, accuracy: 0.5833333730697632
# elapsed time: 0.20770716667175293
# [Epoch: 26 - Training]
# train loss: 0.012284025811823085, accuracy: 0.9791666865348816
# elapsed time: 1.2545878887176514
# [Epoch: 26 - Validation]
# [Batch: 1] running val loss: 0.11110785603523254, running val accuracy: 0.625
# val loss: 0.1142340103785197, accuracy: 0.5833333730697632
# elapsed time: 0.22314786911010742
# [Epoch: 27 - Training]
# train loss: 0.001478111880715005, accuracy: 1.0
# elapsed time: 1.2448060512542725
# [Epoch: 27 - Validation]
# [Batch: 1] running val loss: 0.180616095662117, running val accuracy: 0.5
# val loss: 0.16254917780558267, accuracy: 0.5
# elapsed time: 0.21070098876953125
# [Epoch: 28 - Training]
# train loss: 0.0026095388505685455, accuracy: 1.0
# elapsed time: 1.236027479171753
# [Epoch: 28 - Validation]
# [Batch: 1] running val loss: 0.24152985215187073, running val accuracy: 0.625
# val loss: 0.22532041370868683, accuracy: 0.5833333730697632
# elapsed time: 0.29536008834838867
# [Epoch: 29 - Training]
# train loss: 0.0007550742132783247, accuracy: 1.0
# elapsed time: 1.6061186790466309
# [Epoch: 29 - Validation]
# [Batch: 1] running val loss: 0.09222594648599625, running val accuracy: 0.875
# val loss: 0.10173611342906952, accuracy: 0.75
# elapsed time: 0.28882551193237305
# [Info] best validation accuracy!
# [Epoch: 30 - Training]
# train loss: 0.0016821656220902999, accuracy: 1.0
# elapsed time: 1.2881455421447754
# [Epoch: 30 - Validation]
# [Batch: 1] running val loss: 0.09326887130737305, running val accuracy: 0.625
# val loss: 0.12387329339981079, accuracy: 0.5833333730697632
# elapsed time: 0.20576953887939453
# [Epoch: 31 - Training]
# train loss: 0.0032634253875585273, accuracy: 0.9791666865348816
# elapsed time: 1.2337830066680908
# [Epoch: 31 - Validation]
# [Batch: 1] running val loss: 0.10820087045431137, running val accuracy: 0.75
# val loss: 0.17575127383073172, accuracy: 0.6666666865348816
# elapsed time: 0.206984281539917
# [Epoch: 32 - Training]
# train loss: 0.005538152312510647, accuracy: 0.9791666865348816
# elapsed time: 1.250035047531128
# [Epoch: 32 - Validation]
# [Batch: 1] running val loss: 0.17439505457878113, running val accuracy: 0.625
# val loss: 0.20106529196103415, accuracy: 0.5833333730697632
# elapsed time: 0.21624350547790527
# [Epoch: 33 - Training]
# train loss: 0.0006697588444997867, accuracy: 1.0
# elapsed time: 1.2593402862548828
# [Epoch: 33 - Validation]
# [Batch: 1] running val loss: 0.17413319647312164, running val accuracy: 0.625
# val loss: 0.17530667781829834, accuracy: 0.5833333730697632
# elapsed time: 0.20392727851867676
# [Epoch: 34 - Training]
# train loss: 0.0009626737246435368, accuracy: 1.0
# elapsed time: 1.257716178894043
# [Epoch: 34 - Validation]
# [Batch: 1] running val loss: 0.11314348876476288, running val accuracy: 0.625
# val loss: 0.11528494954109192, accuracy: 0.6666666865348816
# elapsed time: 0.20872879028320312
# [Epoch: 35 - Training]
# train loss: 0.010808663835632615, accuracy: 0.9791666865348816
# elapsed time: 1.2388322353363037
# [Epoch: 35 - Validation]
# [Batch: 1] running val loss: 0.17049053311347961, running val accuracy: 0.875
# val loss: 0.15402647604544958, accuracy: 0.75
# elapsed time: 0.2057783603668213
# [Epoch: 36 - Training]
# train loss: 0.0006591351217745492, accuracy: 1.0
# elapsed time: 1.2301442623138428
# [Epoch: 36 - Validation]
# [Batch: 1] running val loss: 0.2444998323917389, running val accuracy: 0.5
# val loss: 0.22383100787798563, accuracy: 0.5
# elapsed time: 0.2392282485961914
# [Epoch: 37 - Training]
# train loss: 0.009272423558286391, accuracy: 0.9583333730697632
# elapsed time: 1.5906574726104736
# [Epoch: 37 - Validation]
# [Batch: 1] running val loss: 0.16157305240631104, running val accuracy: 0.625
# val loss: 0.14963146050771078, accuracy: 0.5833333730697632
# elapsed time: 0.2939612865447998
# [Epoch: 38 - Training]
# train loss: 0.0016447321913801716, accuracy: 1.0
# elapsed time: 1.367652416229248
# [Epoch: 38 - Validation]
# [Batch: 1] running val loss: 0.16302672028541565, running val accuracy: 0.625
# val loss: 0.16841059923171997, accuracy: 0.5833333730697632
# elapsed time: 0.21091651916503906
# [Epoch: 39 - Training]
# train loss: 0.001871955842943862, accuracy: 1.0
# elapsed time: 1.2360398769378662
# [Epoch: 39 - Validation]
# [Batch: 1] running val loss: 0.17187517881393433, running val accuracy: 0.625
# val loss: 0.20520251989364624, accuracy: 0.5833333730697632
# elapsed time: 0.2079753875732422
# [Epoch: 40 - Training]
# train loss: 0.0028725989165347223, accuracy: 1.0
# elapsed time: 1.2417685985565186
# [Epoch: 40 - Validation]
# [Batch: 1] running val loss: 0.1025671511888504, running val accuracy: 0.625
# val loss: 0.12910544872283936, accuracy: 0.5833333730697632
# elapsed time: 0.21078777313232422
# [Epoch: 41 - Training]
# train loss: 0.00116604156937683, accuracy: 1.0
# elapsed time: 1.243696928024292
# [Epoch: 41 - Validation]
# [Batch: 1] running val loss: 0.22775700688362122, running val accuracy: 0.625
# val loss: 0.19219511995712915, accuracy: 0.5833333730697632
# elapsed time: 0.21358752250671387
# [Epoch: 42 - Training]
# train loss: 0.003349863191639694, accuracy: 1.0
# elapsed time: 1.2496798038482666
# [Epoch: 42 - Validation]
# [Batch: 1] running val loss: 0.2214863896369934, running val accuracy: 0.625
# val loss: 0.2074334720770518, accuracy: 0.5833333730697632
# elapsed time: 0.2152397632598877
# [Epoch: 43 - Training]
# train loss: 0.0007740556854211414, accuracy: 1.0
# elapsed time: 1.2541429996490479
# [Epoch: 43 - Validation]
# [Batch: 1] running val loss: 0.23608586192131042, running val accuracy: 0.75
# val loss: 0.2007344365119934, accuracy: 0.75
# elapsed time: 0.21242237091064453
# [Epoch: 44 - Training]
# train loss: 0.0012873275627498515, accuracy: 1.0
# elapsed time: 1.253479242324829
# [Epoch: 44 - Validation]
# [Batch: 1] running val loss: 0.22929120063781738, running val accuracy: 0.625
# val loss: 0.19437081615130106, accuracy: 0.6666666865348816
# elapsed time: 0.21382784843444824
# [Epoch: 45 - Training]
# train loss: 0.02335508880544997, accuracy: 0.9583333730697632
# elapsed time: 1.5141136646270752
# [Epoch: 45 - Validation]
# [Batch: 1] running val loss: 0.11311287432909012, running val accuracy: 0.75
# val loss: 0.13312385976314545, accuracy: 0.6666666865348816
# elapsed time: 0.30212998390197754
# [Epoch: 46 - Training]
# train loss: 0.004914473742246628, accuracy: 1.0
# elapsed time: 1.4817054271697998
# [Epoch: 46 - Validation]
# [Batch: 1] running val loss: 0.23772193491458893, running val accuracy: 0.75
# val loss: 0.26301079988479614, accuracy: 0.6666666865348816
# elapsed time: 0.22410345077514648
# [Epoch: 47 - Training]
# train loss: 0.003128214909035402, accuracy: 1.0
# elapsed time: 1.2339167594909668
# [Epoch: 47 - Validation]
# [Batch: 1] running val loss: 0.19180667400360107, running val accuracy: 0.5
# val loss: 0.23349140087763467, accuracy: 0.5
# elapsed time: 0.20797443389892578
# [Epoch: 48 - Training]
# train loss: 0.003526790654480768, accuracy: 1.0
# elapsed time: 1.2276313304901123
# [Epoch: 48 - Validation]
# [Batch: 1] running val loss: 0.17517638206481934, running val accuracy: 0.625
# val loss: 0.22020169099171957, accuracy: 0.5833333730697632
# elapsed time: 0.2097759246826172
# [Epoch: 49 - Training]
# train loss: 0.009145206066023093, accuracy: 0.9791666865348816
# elapsed time: 1.2441492080688477
# [Epoch: 49 - Validation]
# [Batch: 1] running val loss: 0.2491472363471985, running val accuracy: 0.5
# val loss: 0.22499161461989084, accuracy: 0.5
# elapsed time: 0.20550894737243652
# [Epoch: 50 - Training]
# train loss: 0.004917513656740387, accuracy: 1.0
# elapsed time: 1.2358965873718262
# [Epoch: 50 - Validation]
# [Batch: 1] running val loss: 0.172624871134758, running val accuracy: 0.625
# val loss: 0.20427282651265463, accuracy: 0.5833333730697632
# elapsed time: 0.2113943099975586
# [Epoch: 51 - Training]
# train loss: 0.010951728545478545, accuracy: 0.9583333730697632
# elapsed time: 1.2389187812805176
# [Epoch: 51 - Validation]
# [Batch: 1] running val loss: 0.24007831513881683, running val accuracy: 0.625
# val loss: 0.27071786920229596, accuracy: 0.5833333730697632
# elapsed time: 0.20618033409118652
# [Epoch: 52 - Training]
# train loss: 0.0034133195683049657, accuracy: 1.0
# elapsed time: 1.2534136772155762
# [Epoch: 52 - Validation]
# [Batch: 1] running val loss: 0.13086189329624176, running val accuracy: 0.5
# val loss: 0.1740908126036326, accuracy: 0.5
# elapsed time: 0.21033406257629395
# [Epoch: 53 - Training]
# train loss: 0.00856989532864342, accuracy: 0.9583333730697632
# elapsed time: 1.3940620422363281
# [Epoch: 53 - Validation]
# [Batch: 1] running val loss: 0.1263975203037262, running val accuracy: 0.5
# val loss: 0.12721565862496695, accuracy: 0.5
# elapsed time: 0.2990272045135498
# [Epoch: 54 - Training]
# train loss: 0.0007515195490365537, accuracy: 1.0
# elapsed time: 1.5804617404937744
# [Epoch: 54 - Validation]
# [Batch: 1] running val loss: 0.24148519337177277, running val accuracy: 0.5
# val loss: 0.20176283021767935, accuracy: 0.5
# elapsed time: 0.2046053409576416
# [Epoch: 55 - Training]
# train loss: 0.002629766400787048, accuracy: 1.0
# elapsed time: 1.238194227218628
# [Epoch: 55 - Validation]
# [Batch: 1] running val loss: 0.19106152653694153, running val accuracy: 0.5
# val loss: 0.23798996210098267, accuracy: 0.5
# elapsed time: 0.2098102569580078
# [Epoch: 56 - Training]
# train loss: 0.015612097757790858, accuracy: 0.9791666865348816
# elapsed time: 1.259732961654663
# [Epoch: 56 - Validation]
# [Batch: 1] running val loss: 0.099995918571949, running val accuracy: 0.75
# val loss: 0.10790629933277766, accuracy: 0.6666666865348816
# elapsed time: 0.20899629592895508
# [Epoch: 57 - Training]
# train loss: 0.003627236951918652, accuracy: 1.0
# elapsed time: 1.2294225692749023
# [Epoch: 57 - Validation]
# [Batch: 1] running val loss: 0.1699216365814209, running val accuracy: 0.5
# val loss: 0.153940183420976, accuracy: 0.5
# elapsed time: 0.2068798542022705
# [Epoch: 58 - Training]
# train loss: 0.003602051675746528, accuracy: 1.0
# elapsed time: 1.24094557762146
# [Epoch: 58 - Validation]
# [Batch: 1] running val loss: 0.24438560009002686, running val accuracy: 0.5
# val loss: 0.22068601349989572, accuracy: 0.5
# elapsed time: 0.21707653999328613
# [Epoch: 59 - Training]
# train loss: 0.003601503439616257, accuracy: 1.0
# elapsed time: 1.2654006481170654
# [Epoch: 59 - Validation]
# [Batch: 1] running val loss: 0.16481047868728638, running val accuracy: 0.625
# val loss: 0.150071382522583, accuracy: 0.5833333730697632
# elapsed time: 0.21074891090393066
# [Epoch: 60 - Training]
# train loss: 0.013090901173806438, accuracy: 0.9375
# elapsed time: 1.2370710372924805
# [Epoch: 60 - Validation]
# [Batch: 1] running val loss: 0.19708725810050964, running val accuracy: 0.5
# val loss: 0.17186815539995828, accuracy: 0.5
# elapsed time: 0.21421384811401367
# [Epoch: 61 - Training]
# train loss: 0.016638946430854656, accuracy: 0.9583333730697632
# elapsed time: 1.2758402824401855
# [Epoch: 61 - Validation]
# [Batch: 1] running val loss: 0.2493293732404709, running val accuracy: 0.625
# val loss: 0.22379093865553537, accuracy: 0.5833333730697632
# elapsed time: 0.29878807067871094
# [Epoch: 62 - Training]
# train loss: 0.0212777142393558, accuracy: 0.9375
# elapsed time: 1.6253700256347656
# [Epoch: 62 - Validation]
# [Batch: 1] running val loss: 0.10875411331653595, running val accuracy: 0.5
# val loss: 0.11281287670135498, accuracy: 0.5
# elapsed time: 0.2840886116027832
# [Epoch: 63 - Training]
# train loss: 0.004415665721656599, accuracy: 0.9791666865348816
# elapsed time: 1.3132729530334473
# [Epoch: 63 - Validation]
# [Batch: 1] running val loss: 0.18469806015491486, running val accuracy: 0.625
# val loss: 0.18377530574798584, accuracy: 0.5833333730697632
# elapsed time: 0.21836447715759277
# [Epoch: 64 - Training]
# train loss: 0.00037697067697687697, accuracy: 1.0
# elapsed time: 1.2298049926757812
# [Epoch: 64 - Validation]
# [Batch: 1] running val loss: 0.17540860176086426, running val accuracy: 0.625
# val loss: 0.1788706382115682, accuracy: 0.5833333730697632
# elapsed time: 0.20584750175476074
# [Epoch: 65 - Training]
# train loss: 0.005561907998829459, accuracy: 1.0
# elapsed time: 1.243931770324707
# [Epoch: 65 - Validation]
# [Batch: 1] running val loss: 0.16198807954788208, running val accuracy: 0.75
# val loss: 0.1521281103293101, accuracy: 0.6666666865348816
# elapsed time: 0.21116304397583008
# [Epoch: 66 - Training]
# train loss: 0.0069002548334538005, accuracy: 1.0
# elapsed time: 1.2426080703735352
# [Epoch: 66 - Validation]
# [Batch: 1] running val loss: 0.2325930893421173, running val accuracy: 0.625
# val loss: 0.213337371746699, accuracy: 0.5833333730697632
# elapsed time: 0.2102818489074707
# [Epoch: 67 - Training]
# train loss: 0.0005253496613780347, accuracy: 1.0
# elapsed time: 1.2388684749603271
# [Epoch: 67 - Validation]
# [Batch: 1] running val loss: 0.1779988706111908, running val accuracy: 0.625
# val loss: 0.1769638160864512, accuracy: 0.5833333730697632
# elapsed time: 0.20321321487426758
# [Epoch: 68 - Training]
# train loss: 0.0031202951237598122, accuracy: 0.9791666865348816
# elapsed time: 1.2432825565338135
# [Epoch: 68 - Validation]
# [Batch: 1] running val loss: 0.1666085571050644, running val accuracy: 0.75
# val loss: 0.2157228191693624, accuracy: 0.6666666865348816
# elapsed time: 0.20789575576782227
# [Epoch: 69 - Training]
# train loss: 0.002268862020476566, accuracy: 1.0
# elapsed time: 1.2459070682525635
# [Epoch: 69 - Validation]
# [Batch: 1] running val loss: 0.16712728142738342, running val accuracy: 0.625
# val loss: 0.15293088555335999, accuracy: 0.5833333730697632
# elapsed time: 0.2130751609802246
# [Epoch: 70 - Training]
# train loss: 0.0061735704900153605, accuracy: 1.0
# elapsed time: 1.6228084564208984
# [Epoch: 70 - Validation]
# [Batch: 1] running val loss: 0.1174442321062088, running val accuracy: 0.5
# val loss: 0.12244322896003723, accuracy: 0.5
# elapsed time: 0.30201125144958496
# [Epoch: 71 - Training]
# train loss: 0.007396735759054233, accuracy: 0.9791666865348816
# elapsed time: 1.389216661453247
# [Epoch: 71 - Validation]
# [Batch: 1] running val loss: 0.19227002561092377, running val accuracy: 0.5
# val loss: 0.18726765116055807, accuracy: 0.5
# elapsed time: 0.21093344688415527
# [Epoch: 72 - Training]
# train loss: 0.008605136522116178, accuracy: 0.9791666865348816
# elapsed time: 1.241591215133667
# [Epoch: 72 - Validation]
# [Batch: 1] running val loss: 0.10045138001441956, running val accuracy: 0.75
# val loss: 0.10809422036012013, accuracy: 0.6666666865348816
# elapsed time: 0.2083275318145752
# [Epoch: 73 - Training]
# train loss: 0.013762308211880736, accuracy: 0.9583333730697632
# elapsed time: 1.2401282787322998
# [Epoch: 73 - Validation]
# [Batch: 1] running val loss: 0.2630262076854706, running val accuracy: 0.5
# val loss: 0.2666478951772054, accuracy: 0.5
# elapsed time: 0.20924735069274902
# [Epoch: 74 - Training]
# train loss: 0.0045358964198385365, accuracy: 1.0
# elapsed time: 1.2453131675720215
# [Epoch: 74 - Validation]
# [Batch: 1] running val loss: 0.24605289101600647, running val accuracy: 0.625
# val loss: 0.2277197539806366, accuracy: 0.5833333730697632
# elapsed time: 0.20341873168945312
# [Epoch: 75 - Training]
# train loss: 0.008003393401547024, accuracy: 0.9791666865348816
# elapsed time: 1.245732069015503
# [Epoch: 75 - Validation]
# [Batch: 1] running val loss: 0.12653738260269165, running val accuracy: 0.5
# val loss: 0.13007048765818277, accuracy: 0.5833333730697632
# elapsed time: 0.20833683013916016
# [Epoch: 76 - Training]
# train loss: 0.0018788904271787032, accuracy: 1.0
# elapsed time: 1.2898590564727783
# [Epoch: 76 - Validation]
# [Batch: 1] running val loss: 0.10677574574947357, running val accuracy: 0.625
# val loss: 0.13027610381444296, accuracy: 0.5833333730697632
# elapsed time: 0.2076258659362793
# [Epoch: 77 - Training]
# train loss: 0.005183507819310762, accuracy: 0.9791666865348816
# elapsed time: 1.247284173965454
# [Epoch: 77 - Validation]
# [Batch: 1] running val loss: 0.24722231924533844, running val accuracy: 0.5
# val loss: 0.22281942764918009, accuracy: 0.5
# elapsed time: 0.20582818984985352
# [Epoch: 78 - Training]
# train loss: 0.004149020854432213, accuracy: 1.0
# elapsed time: 1.5210041999816895
# [Epoch: 78 - Validation]
# [Batch: 1] running val loss: 0.17752400040626526, running val accuracy: 0.625
# val loss: 0.17608747879664102, accuracy: 0.5833333730697632
# elapsed time: 0.308124303817749
# [Epoch: 79 - Training]
# train loss: 0.0032385545358314025, accuracy: 1.0
# elapsed time: 1.4653542041778564
# [Epoch: 79 - Validation]
# [Batch: 1] running val loss: 0.2533908784389496, running val accuracy: 0.5
# val loss: 0.21183289090792337, accuracy: 0.5833333730697632
# elapsed time: 0.20763230323791504
# [Epoch: 80 - Training]
# train loss: 0.0037871391638570153, accuracy: 1.0
# elapsed time: 1.2459847927093506
# [Epoch: 80 - Validation]
# [Batch: 1] running val loss: 0.1804780215024948, running val accuracy: 0.5
# val loss: 0.2267072598139445, accuracy: 0.5
# elapsed time: 0.20739269256591797
# [Epoch: 81 - Training]
# train loss: 0.013717318059207173, accuracy: 0.9583333730697632
# elapsed time: 1.2373106479644775
# [Epoch: 81 - Validation]
# [Batch: 1] running val loss: 0.18790167570114136, running val accuracy: 0.5
# val loss: 0.22931678096453348, accuracy: 0.5
# elapsed time: 0.20460724830627441
# [Epoch: 82 - Training]
# train loss: 0.01798039052907067, accuracy: 0.9375
# elapsed time: 1.2404913902282715
# [Epoch: 82 - Validation]
# [Batch: 1] running val loss: 0.11072511970996857, running val accuracy: 0.625
# val loss: 0.1826618810494741, accuracy: 0.5833333730697632
# elapsed time: 0.21172261238098145
# [Epoch: 83 - Training]
# train loss: 0.014382954851801818, accuracy: 0.9583333730697632
# elapsed time: 1.243607997894287
# [Epoch: 83 - Validation]
# [Batch: 1] running val loss: 0.24125352501869202, running val accuracy: 0.625
# val loss: 0.2038467675447464, accuracy: 0.6666666865348816
# elapsed time: 0.20414471626281738
# [Epoch: 84 - Training]
# train loss: 0.010330096023002019, accuracy: 0.9583333730697632
# elapsed time: 1.2375118732452393
# [Epoch: 84 - Validation]
# [Batch: 1] running val loss: 0.10962074995040894, running val accuracy: 0.625
# val loss: 0.16269334157307944, accuracy: 0.5833333730697632
# elapsed time: 0.2215728759765625
# [Epoch: 85 - Training]
# train loss: 0.0011724249973970775, accuracy: 1.0
# elapsed time: 1.2526240348815918
# [Epoch: 85 - Validation]
# [Batch: 1] running val loss: 0.09824219346046448, running val accuracy: 0.625
# val loss: 0.17524937788645426, accuracy: 0.5833333730697632
# elapsed time: 0.20968031883239746
# [Epoch: 86 - Training]
# train loss: 0.0011813174448131274, accuracy: 1.0
# elapsed time: 1.3938677310943604
# [Epoch: 86 - Validation]
# [Batch: 1] running val loss: 0.18229612708091736, running val accuracy: 0.5
# val loss: 0.18375828365484873, accuracy: 0.5
# elapsed time: 0.29749059677124023
# [Epoch: 87 - Training]
# train loss: 0.008543234008053938, accuracy: 0.9791666865348816
# elapsed time: 1.5666232109069824
# [Epoch: 87 - Validation]
# [Batch: 1] running val loss: 0.25096815824508667, running val accuracy: 0.5
# val loss: 0.2545665701230367, accuracy: 0.5
# elapsed time: 0.20730924606323242
# [Epoch: 88 - Training]
# train loss: 0.0006512712025141809, accuracy: 1.0
# elapsed time: 1.2441270351409912
# [Epoch: 88 - Validation]
# [Batch: 1] running val loss: 0.10511937737464905, running val accuracy: 0.625
# val loss: 0.1311347782611847, accuracy: 0.5833333730697632
# elapsed time: 0.2159113883972168
# [Epoch: 89 - Training]
# train loss: 0.004532685622204251, accuracy: 1.0
# elapsed time: 1.2493181228637695
# [Epoch: 89 - Validation]
# [Batch: 1] running val loss: 0.24922031164169312, running val accuracy: 0.5
# val loss: 0.274411420027415, accuracy: 0.5
# elapsed time: 0.2089252471923828
# [Epoch: 90 - Training]
# train loss: 0.00052543717053292, accuracy: 1.0
# elapsed time: 1.243375301361084
# [Epoch: 90 - Validation]
# [Batch: 1] running val loss: 0.11546939611434937, running val accuracy: 0.5
# val loss: 0.17787330349286398, accuracy: 0.5
# elapsed time: 0.21628189086914062
# [Epoch: 91 - Training]
# train loss: 0.0011811681348869267, accuracy: 1.0
# elapsed time: 1.2573018074035645
# [Epoch: 91 - Validation]
# [Batch: 1] running val loss: 0.16061951220035553, running val accuracy: 0.625
# val loss: 0.165572722752889, accuracy: 0.5833333730697632
# elapsed time: 0.2087554931640625
# [Epoch: 92 - Training]
# train loss: 0.008264057721438197, accuracy: 0.9791666865348816
# elapsed time: 1.2467536926269531
# [Epoch: 92 - Validation]
# [Batch: 1] running val loss: 0.09149760007858276, running val accuracy: 0.75
# val loss: 0.1388783504565557, accuracy: 0.6666666865348816
# elapsed time: 0.20960330963134766
# [Epoch: 93 - Training]
# train loss: 0.0011520357596358128, accuracy: 1.0
# elapsed time: 1.2467331886291504
# [Epoch: 93 - Validation]
# [Batch: 1] running val loss: 0.16517533361911774, running val accuracy: 0.75
# val loss: 0.17265159885088602, accuracy: 0.6666666865348816
# elapsed time: 0.20889639854431152
# [Epoch: 94 - Training]
# train loss: 0.007209786652917198, accuracy: 0.9583333730697632
# elapsed time: 1.3143010139465332
# [Epoch: 94 - Validation]
# [Batch: 1] running val loss: 0.10123009979724884, running val accuracy: 0.75
# val loss: 0.17215083042780557, accuracy: 0.6666666865348816
# elapsed time: 0.3060014247894287
# [Epoch: 95 - Training]
# train loss: 0.0026677364027515673, accuracy: 1.0
# elapsed time: 1.6137027740478516
# [Epoch: 95 - Validation]
# [Batch: 1] running val loss: 0.11337731778621674, running val accuracy: 0.75
# val loss: 0.1797519028186798, accuracy: 0.6666666865348816
# elapsed time: 0.30042529106140137
# [Epoch: 96 - Training]
# train loss: 0.018960606432907905, accuracy: 0.9583333730697632
# elapsed time: 1.2568528652191162
# [Epoch: 96 - Validation]
# [Batch: 1] running val loss: 0.18824203312397003, running val accuracy: 0.5
# val loss: 0.16901890436808267, accuracy: 0.5
# elapsed time: 0.2086498737335205
# [Epoch: 97 - Training]
# train loss: 0.014259569861072427, accuracy: 0.9583333730697632
# elapsed time: 1.2275919914245605
# [Epoch: 97 - Validation]
# [Batch: 1] running val loss: 0.09635478258132935, running val accuracy: 0.875
# val loss: 0.1516564985116323, accuracy: 0.75
# elapsed time: 0.2289140224456787
# [Epoch: 98 - Training]
# train loss: 0.0019401381287025288, accuracy: 1.0
# elapsed time: 1.2489280700683594
# [Epoch: 98 - Validation]
# [Batch: 1] running val loss: 0.17676162719726562, running val accuracy: 0.625
# val loss: 0.18004468083381653, accuracy: 0.5833333730697632
# elapsed time: 0.20964837074279785
# [Epoch: 99 - Training]
# train loss: 0.008530364527056614, accuracy: 0.9791666865348816
# elapsed time: 1.2590737342834473
# [Epoch: 99 - Validation]
# [Batch: 1] running val loss: 0.16680678725242615, running val accuracy: 0.75
# val loss: 0.15561383465925852, accuracy: 0.6666666865348816
# elapsed time: 0.2207794189453125
# [Epoch: 100 - Training]
# train loss: 0.005025277898918527, accuracy: 1.0
# elapsed time: 1.2334349155426025
# [Epoch: 100 - Validation]
# [Batch: 1] running val loss: 0.1763457953929901, running val accuracy: 0.625
# val loss: 0.20425331592559814, accuracy: 0.5833333730697632
# elapsed time: 0.2092742919921875

# %% [markdown]
# ## 결과 시각화

# %%
plt.plot([x[0] for x in history], 'b', label='train')
plt.plot([x[1] for x in history], 'r--',label='validation')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()

# %%
plt.plot([x[0] for x in accuracy], 'b', label='train')
plt.plot([x[1] for x in accuracy], 'r--',label='validation')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()

# %%
model = models.resnet50(pretrained=True)
num_features = model.fc.in_features
model.fc = nn.Linear(num_features, 3) # transfer learning
model = model.cuda()
model_path = 'last_checkpoint.pth'
model.load_state_dict(torch.load(model_path))

test_loss, test_accuracy = test()
print(f"Test loss: {test_loss:.8f}")
print(f"Test accuracy: {test_accuracy * 100.:.2f}%")
# Out:
# [Test]
# [Batch: 1] running test loss: 0.04228537902235985, running test accuracy: 0.875
# test loss: 0.24820890724658967, accuracy: 0.5666667222976685
# elapsed time: 0.4857659339904785
# Test loss: 0.24820891
# Test accuracy: 56.67%
